# %%
#objective
### Data
#We have provided you with a dataset of app reviews for the popular reddit app. The CSV file has multiple flaws 
#and falls short of what we would like to work with, as is often the case and therefore we want you to fix it.

### Expected Output
#We expect you to parse the file and make sure that things are consistent and as orderly as possible. 
#For example the app_bought and money_spent variables should be available in buckets (feel free to choose the buckets yourself).
#We will leave it to you to define what is desirable.

# %%
#import libraries
import pandas as pd
import numpy as np
import sqlite3 as sq

# %%
#data path
path = "/Users/edima/Documents/Coding/code_interview_questions/data-challenge-master/"

# %%
#load reddit data
df = pd.read_csv(path + 'reddit_exercise_data.csv')
df.dtypes
print(df)
# Out:
#                                                   title  \
# 0                                              Love it!
# 1                                                   •••
# 2                                         Very good app
# 3                                              CNN here
# 4                                           Easy peasy!
# 5                                             Reddit!!!
# 6                                          Good reading
# 7                                           Works great
# 8                            App is better than website
# 9                                     Great Time Waster
# 10                                   Just like the site
# 11                                        Really Smooth
# 12                                                  Fun
# 13                                                 Bool
# 14                                           Excellent!
# 15                           Easier than through safari
# ...

# %%
#load sqlite db
# Read sqlite query results into a pandas DataFrame
con = sq.connect(path + "exercise_database.db")
#df = pd.read_sql_query("SELECT *", con)

# verify that result of SQL query is stored in the dataframe
#print(df.head())

con.close()
